# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (10,8)
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['xtick.labelsize']=14
plt.rcParams['ytick.labelsize']=14
plt.rcParams['legend.fontsize']=12

# %%
dictionary={'how-bert':14.6,'how-distilbert':17,'other-bert':11.8,'other-distilbert':11.9,'what-bert':14,'what-distilbert':15.8,
     'when-bert':18,'when-distilbert':20.2,'where-bert':9.7,'where-distilbert':10.3,'which-bert':17.8,'which-distilbert':19.1,
     'who-bert':22.9,'who-distilbert':19.4}

# %%
plt.bar(dictionary.keys(),dictionary.values(),color=['#c00c0f','#c00c0f','#e9164b','#e9164b','#eb2863','#eb2863','#fd0d6d','#fd0d6d','#F55E61','#F55E61','#f9585a','#f9585a','#fd3a6b','#fd3a6b','#fa7a7c','#fa7a7c','#fe7798','#fe7798'])
plt.title('Percentage of exact matches by type of data and model used')
plt.xlabel('Type of question and model used')
plt.xticks(rotation=90)
plt.ylabel('% of exact matches')
# Out:
# Text(0,0.5,'% of exact matches')

# %%
dictionary2={'how-bert':0.217,'how-distilbert':0.243,'other-bert':0.195,'other-distilbert':0.194,'what-bert':0.238,'what-distilbert':0.243,
     'when-bert':0.277,'when-distilbert':0.301,'where-bert':0.217,'where-distilbert':0.206,'which-bert':0.279,'which-distilbert':0.285,
     'who-bert':0.292,'who-distilbert':0.255}

# %%
plt.bar(dictionary2.keys(),dictionary2.values(),color=['#c00c0f','#c00c0f','#e9164b','#e9164b','#eb2863','#eb2863','#fd0d6d','#fd0d6d','#F55E61','#F55E61','#f9585a','#f9585a','#fd3a6b','#fd3a6b','#fa7a7c','#fa7a7c','#fe7798','#fe7798'])
plt.title('F1 score by type of data and model used')
plt.xlabel('Type of question and model used')
plt.xticks(rotation=90)
plt.ylabel('F1 score')
# Out:
# Text(0,0.5,'F1 score')

# %%
dictionary3={'how-bert':50.926,'how-distilbert':34.466,'other-bert':37.986,'other-distilbert':25.504,'what-bert':40.096,'what-distilbert':27.201,
     'when-bert':54.561,'when-distilbert':37.2,'where-bert':38.367,'where-distilbert':25.878,'which-bert':31.653,'which-distilbert':21.31,
     'who-bert':44.854 ,'who-distilbert':29.782}

plt.bar(dictionary3.keys(),dictionary3.values(),color=['#c00c0f','#c00c0f','#e9164b','#e9164b','#eb2863','#eb2863','#fd0d6d','#fd0d6d','#F55E61','#F55E61','#f9585a','#f9585a','#fd3a6b','#fd3a6b','#fa7a7c','#fa7a7c','#fe7798','#fe7798'])
plt.title('Time it took to fit and evaluate by type of data and model used')
plt.xlabel('Type of question and model used')
plt.xticks(rotation=90)
plt.ylabel('min')
# Out:
# Text(0,0.5,'min')
